# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

# prevent ultralytics from tracking your activity
# !yolo settings sync=False

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.5.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 32.0/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on 4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg
# {'predictions': [{'x': 1227.0,
#    'y': 527.5,
#    'width': 50.0,
#    'height': 77.0,
#    'confidence': 0.9045102000236511,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '7bb0de78-c58d-454a-b693-c3f518f94f80',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 731.0,
#    'y': 584.5,
#    'width': 52.0,
#    'height': 79.0,
#    'confidence': 0.8924632668495178,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'b3ea8a5a-5294-45c9-9221-ba8a6f0884b5',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1397.5,
#    'y': 344.5,
#    'width': 31.0,
#    'height': 55.0,
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mEHKTXuTFl1Fp8vcqosj")
project = rf.workspace("ama-mwfd1").project("trash-detection-ujrn0-gesq6")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 18.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 79.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 142.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Trash-Detection-1 in yolov8:: 100%|██████████| 4547/4547 [00:01<00:00, 3570.05it/s]

# %%
from google.colab import drive
import os

# Ensure the mount point is clean before attempting to mount
if os.path.isdir('/content/drive'):
    try:
        # Attempt to unmount if it's a mounted directory
        # !fusermount -u /content/drive
    except:
        pass # Ignore errors if it's not mounted or cannot be unmounted
    # Remove the directory if it's still there and not empty
    if os.path.isdir('/content/drive') and len(os.listdir('/content/drive')) > 0:
        # !rm -rf /content/drive/*
        # !rmdir /content/drive # Remove the directory itself after clearing contents

drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="mEHKTXuTFl1Fp8vcqosj")
project = rf.workspace("ama-mwfd1").project("trash-detection-ujrn0-gesq6")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 285.0/285.0 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 23.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 74.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 kB 5.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 5.0.0.93
#     Uninstalling opencv-python-headless-5.0.0.93:
#       Successfully uninstalled opencv-python-headless-5.0.0.93
#   Attempting uninstall: typer
#     Found existing installation: typer 0.26.8
#     Uninstalling typer-0.26.8:
#       Successfully uninstalled typer-0.26.8
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Trash-Detection-1 in yolov8:: 100%|██████████| 4547/4547 [00:01<00:00, 3614.51it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=Trash-Detection-1/data.yaml epochs=100 imgsz=640 project="/content/drive/MyDrive/SABIT/Projek Semester 3"
# Out:
# Ultralytics 8.4.105 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.1/46.1 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 21.9 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model="/content/drive/MyDrive/SABIT/Projek Semester 3/train/weights/last.pt" resume=True
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.106 🚀 Python-3.12.13 torch-2.11.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
